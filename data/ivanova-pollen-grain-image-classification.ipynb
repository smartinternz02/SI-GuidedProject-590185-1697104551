# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\new folder\python3106\lib\site-packages (1.26.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Importing necessary libraries 
import os
import cv2
from PIL import Image
import numpy as np 
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from collections import Counter
from sklearn.metrics import confusion_matrix

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Activation, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# path of image folder
path  = '/kaggle/input/pollen-grain-image-classification/'

names = [name.replace(' ', '_').split('_')[0] for name in os.listdir(path)]
classes = Counter(names)  #returns dictionary

print("Total number of images is {}".format(len(names)))
# Out:
# Total number of images is 790

# %%
plt.figure(figsize = (12,8))
plt.title('Class Counts in Dataset')
plt.bar(*zip(*classes.items()))
plt.xticks(rotation='vertical')
plt.show()

# %%
path_class  = {key:[] for key in classes.keys()}

for name in os.listdir(path):
    key = name.replace(' ', '_').split('_')[0]
    path_class[key].append(path + name)

# %%
fig = plt.figure(figsize=(15, 15))
for i, key in enumerate(path_class.keys()):
    img1 = Image.open(path_class[key][0]) 
    img2 = Image.open(path_class[key][1]) 
    img3 = Image.open(path_class[key][2]) 

    ax = fig.add_subplot(8, 9,  3*i + 1, xticks=[], yticks=[])
    ax.imshow(img1)
    ax.set_title(key)
    
    ax = fig.add_subplot(8, 9,  3*i + 2, xticks=[], yticks=[])
    ax.imshow(img2)
    ax.set_title(key)

    ax = fig.add_subplot(8, 9,  3*i + 3, xticks=[], yticks=[])
    ax.imshow(img3)
    ax.set_title(key)

# %%
size = [cv2.imread(path + name).shape for name in os.listdir(path)]
x, y, _ = zip(*size)

fig = plt.figure(figsize=(12, 10))
# scatter plot
plt.scatter(x,y)
plt.title("Image size scatterplot")

# add diagonal red line 
plt.plot([0,800],[0,800], 'r')

# %%
def process_img(img, size = (128,128)):
    img = cv2.resize(img, size)  # resize image
    img = img/255                   # devide values to 255
    return img   

def plot_confusion_matrix(model, x, y, plot_title = ''):
    y_pred = model.predict(x)                            # get predictions on x using model
    predicted_categories = tf.argmax(y_pred, axis=1)     # get index of predicted category
    true_categories = tf.argmax(y, axis=1)               # get index of true category
    # create confusion matrix using sklearn
    cm = confusion_matrix(true_categories, predicted_categories)
    # create DataFrame from the confusion matrix. We retrieve labels from LabelEncoder.
    df_cm = pd.DataFrame(cm, index = le.classes_ ,  columns = le.classes_)
    # divide each row to its sum in the DataFrame to get normalized output
    df_cm = df_cm.div(df_cm.sum(axis=1), axis=0)
    
    plt.figure(figsize = (15,12))
    plt.title(plot_title)
    sns.heatmap(df_cm, annot=True)

# %%
# Read all images and put in X variable, Y variable is class names
X, Y = [], []
for name  in os.listdir(path):
    img = cv2.imread(path + name)
    X.append(process_img(img))
    Y.append(name.replace(' ', '_').split('_')[0])

X = np.array(X)

# %%
le = LabelEncoder()
Y_le = le.fit_transform(Y)
Y_cat = np_utils.to_categorical(Y_le, 23)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y_cat, test_size=0.285, stratify=Y_le)
print("Images in each class in Test set: {}".format(np.sum(Y_test, axis =0)))
# Out:
# Images in each class in Test set: [ 6. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10.
#  10. 10. 10. 10. 10.]

# %%
input_shape =  X_train[0].shape
output_shape = 23

model = Sequential()
model.add(Conv2D(filters = 16, kernel_size = 3, input_shape = input_shape, activation= 'relu', padding='same'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters = 32, kernel_size = 2, activation= 'relu', padding='same'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters = 64, kernel_size = 2, activation= 'relu', padding='same'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters = 128, kernel_size = 2, activation= 'relu', padding='same'))
model.add(MaxPooling2D(pool_size=2))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(500, activation = 'relu'))
model.add(Dense(150, activation = 'relu'))
model.add(Dense(output_shape, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        2080
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        8256
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       32896
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dropout (Dropout)           (None, 8192)              0
#
#  dense (Dense)               (None, 500)               4096500
#
#  dense_1 (Dense)             (None, 150)               75150
#
#  dense_2 (Dense)             (None, 23)                3473
#
# =================================================================
# Total params: 4,218,803
# Trainable params: 4,218,803
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', metrics=['accuracy'])
print('Model is Compiled!')
# Out:
# Model is Compiled!

# %%
datagener = ImageDataGenerator(
                rotation_range= 20,
                width_shift_range = 0.2,
                height_shift_range = 0.2,
                horizontal_flip = True,
                vertical_flip = True,)
# fit data generator
datagener.fit(X_train)

# %%
batch_size = 4
epochs = 500

model_path = 'cnn.hdf5'
callbecks = [EarlyStopping(monitor ='val_loss', patience = 20), 
             ModelCheckpoint(filepath = model_path, save_best_only = True)]


history = model.fit(
        datagener.flow(X_train, Y_train, batch_size=batch_size), 
        batch_size = batch_size, 
        steps_per_epoch = len(X_train) // batch_size,
        epochs = epochs,
        validation_data = (X_train, Y_train),
        callbacks = callbecks,
        verbose = 1)
# Out:
# Epoch 1/500
# 141/141 [==============================] - 12s 83ms/step - loss: 1.3827 - accuracy: 0.4982 - val_loss: 1.6589 - val_accuracy: 0.4592
# Epoch 2/500
# 141/141 [==============================] - 12s 86ms/step - loss: 1.3509 - accuracy: 0.5053 - val_loss: 1.1623 - val_accuracy: 0.5745
# Epoch 3/500
# 141/141 [==============================] - 12s 86ms/step - loss: 1.3254 - accuracy: 0.5390 - val_loss: 1.1529 - val_accuracy: 0.5780
# Epoch 4/500
# 141/141 [==============================] - 12s 88ms/step - loss: 1.3262 - accuracy: 0.5408 - val_loss: 0.8794 - val_accuracy: 0.6862
# Epoch 5/500
# 141/141 [==============================] - 12s 83ms/step - loss: 1.2484 - accuracy: 0.5851 - val_loss: 0.9497 - val_accuracy: 0.6401
# Epoch 6/500
# 141/141 [==============================] - 12s 84ms/step - loss: 1.2399 - accuracy: 0.5656 - val_loss: 1.3639 - val_accuracy: 0.5550
# Epoch 7/500
# 141/141 [==============================] - 13s 89ms/step - loss: 1.2028 - accuracy: 0.6046 - val_loss: 0.7923 - val_accuracy: 0.7145
# Epoch 8/500
# 141/141 [==============================] - 12s 85ms/step - loss: 1.1540 - accuracy: 0.5957 - val_loss: 0.8557 - val_accuracy: 0.6862
# Epoch 9/500
# 141/141 [==============================] - 12s 87ms/step - loss: 1.1789 - accuracy: 0.5709 - val_loss: 0.7245 - val_accuracy: 0.7323
# Epoch 10/500
# 141/141 [==============================] - 12s 84ms/step - loss: 1.1302 - accuracy: 0.6011 - val_loss: 0.6895 - val_accuracy: 0.7465
# Epoch 11/500
# 141/141 [==============================] - 12s 83ms/step - loss: 1.0910 - accuracy: 0.6064 - val_loss: 0.8243 - val_accuracy: 0.6720
# Epoch 12/500
# 141/141 [==============================] - 12s 86ms/step - loss: 1.1028 - accuracy: 0.5940 - val_loss: 0.9836 - val_accuracy: 0.6560
# Epoch 13/500
500
# 141/141 [==============================] - 12s 86ms/step - loss: 0.6451 - accuracy: 0.8121 - val_loss: 0.2420 - val_accuracy: 0.9167
# Epoch 91/500
# 141/141 [==============================] - 12s 82ms/step - loss: 0.6378 - accuracy: 0.8032 - val_loss: 0.2937 - val_accuracy: 0.8936
# Epoch 92/500
# 141/141 [==============================] - 12s 83ms/step - loss: 0.6062 - accuracy: 0.8298 - val_loss: 0.2493 - val_accuracy: 0.9096
# Epoch 93/500
# 141/141 [==============================] - 13s 91ms/step - loss: 0.6597 - accuracy: 0.8316 - val_loss: 0.1828 - val_accuracy: 0.9415
# Epoch 94/500
# 141/141 [==============================] - 12s 88ms/step - loss: 0.7359 - accuracy: 0.8262 - val_loss: 0.4066 - val_accuracy: 0.8723
# Epoch 95/500
# 141/141 [==============================] - 13s 89ms/step - loss: 0.5607 - accuracy: 0.8422 - val_loss: 0.9554 - val_accuracy: 0.7748
# Epoch 96/500
# 141/141 [==============================] - 13s 90ms/step - loss: 0.6750 - accuracy: 0.8262 - val_loss: 0.9616 - val_accuracy: 0.7943
# Epoch 97/500
# 141/141 [==============================] - 13s 93ms/step - loss: 0.6413 - accuracy: 0.8174 - val_loss: 0.2429 - val_accuracy: 0.9220
# Epoch 98/500
# 141/141 [==============================] - 12s 88ms/step - loss: 0.6267 - accuracy: 0.8067 - val_loss: 0.8965 - val_accuracy: 0.7837
# Epoch 99/500
# 141/141 [==============================] - 12s 85ms/step - loss: 0.6028 - accuracy: 0.8280 - val_loss: 0.3945 - val_accuracy: 0.8564
# Epoch 100/500
# 141/141 [==============================] - 12s 84ms/step - loss: 0.6524 - accuracy: 0.8174 - val_loss: 0.4442 - val_accuracy: 0.8936
# Epoch 101/500
# 141/141 [==============================] - 12s 88ms/step - loss: 0.6364 - accuracy: 0.8404 - val_loss: 0.2839 - val_accuracy: 0.9238
# Epoch 102/500
# 141/141 [==============================] - 12s 86ms/step - loss: 0.5983 - accuracy: 0.8191 - val_loss: 0.3287 - val_accuracy: 0.9131

# %%
model.load_weights(model_path)
score = model.evaluate(X_test, Y_test, verbose=0)
print('Test set accuracy: {}'.format(score[1]))
# Out:
# Test set accuracy: 0.8672566413879395

# %%
plot_confusion_matrix(model, X_train, Y_train, "Train set")
plot_confusion_matrix(model, X_test,  Y_test,  "Test set")
# Out:
# 18/18 [==============================] - 2s 80ms/step
# 8/8 [==============================] - 1s 67ms/step

# %%
plt.figure(figsize = (15,12))     
   
plt.subplot(211)  
plt.title('Model Accuracy')  
plt.plot(history.history['accuracy'])  
plt.plot(history.history['val_accuracy'])  
plt.ylabel('Accuracy')  
plt.xlabel('Epoch')  
plt.legend(['Generated Data', 'Original Train Data'], loc='best')  
      
plt.subplot(212)  
plt.plot(history.history['loss'])  
plt.plot(history.history['val_loss'])  
plt.title('Model Loss')  
plt.ylabel('Categorical Crossentropy')  
plt.xlabel('Epoch')  
plt.legend(['Generated Data', 'Original Train Data'], loc='best')  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\MIRZA SHOAIB ALI\Downloads\ivanova-pollen-grain-image-classification.ipynb Cell 17 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/MIRZA%20SHOAIB%20ALI/Downloads/ivanova-pollen-grain-image-classification.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize = (15,12))
#       <a href='vscode-notebook-cell:/c%3A/Users/MIRZA%20SHOAIB%20ALI/Downloads/ivanova-pollen-grain-image-classification.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> plt.subplot(211)
#       <a href='vscode-notebook-cell:/c%3A/Users/MIRZA%20SHOAIB%20ALI/Downloads/ivanova-pollen-grain-image-classification.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> plt.title('Model Accuracy')
#
# NameError: name 'plt' is not defined
